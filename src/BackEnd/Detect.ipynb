# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
DATA_PATH = ''
actions = []
no_sequences = 30
sequence_length = 30

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
# cap.release()
# cv2.destroyAllWindows()

# %%
draw_landmarks(frame, results)
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('Sign_Data') 

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
# cap.release()
# cv2.destroyAllWindows()

# %%
# %pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 label_map = {label:num for num, label in enumerate(actions)}
#
# NameError: name 'actions' is not defined

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (90, 30, 1662)

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime
from tensorflow.keras.models import load_model

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
def get_timestamp():
    return datetime.now().strftime('%Y%m%d_%H%M%S')

# %%
checkpoint_callback = ModelCheckpoint(
    filepath=f'best_model_{get_timestamp()}.keras',         # Path where the model will be saved
    monitor='categorical_accuracy',               # Monitor training accuracy
    save_best_only=True,              # Save only when accuracy improves
    mode='max',                       # Save when accuracy is maximized
    verbose=1                         # Print messages when saving
)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 9s 164ms/step - loss: 2.6538 - categorical_accuracy: 0.4588
# Epoch 2/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 14.1488 - categorical_accuracy: 0.3176
# Epoch 3/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 6.4449 - categorical_accuracy: 0.3647
# Epoch 4/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 3.7177 - categorical_accuracy: 0.3412
# Epoch 5/2000
# 3/3 [==============================] - 1s 167ms/step - loss: 14.8501 - categorical_accuracy: 0.2706
# Epoch 6/2000
# 3/3 [==============================] - 0s 170ms/step - loss: 5.2385 - categorical_accuracy: 0.3882
# Epoch 7/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 13.4127 - categorical_accuracy: 0.3176
# Epoch 8/2000
# 3/3 [==============================] - 0s 170ms/step - loss: 9.1803 - categorical_accuracy: 0.3294
# Epoch 9/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 9.4507 - categorical_accuracy: 0.3059
# Epoch 10/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 5.1748 - categorical_accuracy: 0.4353
# Epoch 11/2000
# 3/3 [==============================] - 1s 180ms/step - loss: 5.4118 - categorical_accuracy: 0.2235
# Epoch 12/2000
# 3/3 [==============================] - 1s 194ms/step - loss: 5.2661 - categorical_accuracy: 0.3294
# Epoch 13/2000
# 3/3 [==============================] - 1s 248ms/step - loss: 12.3910 - categorical_accuracy: 0.3882
# Epoch 14/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 13.6726 - categorical_accuracy: 0.3529
# Epoch 15/2000
# 3/3 [==============================] - 0s 167ms/step - loss: 8.3244 - categorical_accuracy: 0.3529
# Epoch 16/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 9.2510 - categorical_accuracy: 0.4000
# Epoch 17/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 5.9577 - categorical_accuracy: 0.3412
# Epoch 18/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 12.4628 - categorical_accuracy: 0.3529
# Epoch 19/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 8.3095 - categorical_accuracy: 0.2588
# Epoch 20/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 9.2247 - categorical_accuracy: 0.3647
# Epoch 21/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 71.0403 - categorical_accuracy: 0.2941
# Epoch 22/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 31.9411 - categorical_accuracy: 0.3412
# Epoch 23/2000
# 3/3 [==============================] - 1s 220ms/step - loss: 17.1017 - categorical_accuracy: 0.3059
# Epoch 24/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 18.3524 - categorical_accuracy: 0.3647
# Epoch 25/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 43.2117 - categorical_accuracy: 0.2824
# Epoch 26/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 7.2798 - categorical_accuracy: 0.2706
# Epoch 27/2000
# 3/3 [==============================] - 1s 223ms/step - loss: 9.7099 - categorical_accuracy: 0.3294
# Epoch 28/2000
# 3/3 [==============================] - 1s 202ms/step - loss: 3.0454 - categorical_accuracy: 0.4000
# Epoch 29/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 3.0574 - categorical_accuracy: 0.3765
# Epoch 30/2000
# 3/3 [==============================] - 1s 198ms/step - loss: 2.2308 - categorical_accuracy: 0.4235
# Epoch 31/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 1.9705 - categorical_accuracy: 0.3412
# Epoch 32/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 1.8261 - categorical_accuracy: 0.3176
# Epoch 33/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 1.4185 - categorical_accuracy: 0.3176
# Epoch 34/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 1.2306 - categorical_accuracy: 0.2941
# Epoch 35/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 1.1257 - categorical_accuracy: 0.4235
# Epoch 36/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 1.0946 - categorical_accuracy: 0.4235
# Epoch 37/2000
# 3/3 [==============================] - 0s 169ms/step - loss: 1.2838 - categorical_accuracy: 0.4000
# Epoch 38/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 0.9384 - categorical_accuracy: 0.4471
# Epoch 39/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.3042 - categorical_accuracy: 0.4235
# Epoch 40/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 1.2935 - categorical_accuracy: 0.4471
# Epoch 41/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 1.3001 - categorical_accuracy: 0.4118
# Epoch 42/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 1.2201 - categorical_accuracy: 0.4941
# Epoch 43/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 1.0446 - categorical_accuracy: 0.5765
# Epoch 44/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 1.0961 - categorical_accuracy: 0.4235
# Epoch 45/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 1.0772 - categorical_accuracy: 0.4824
# Epoch 46/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.1439 - categorical_accuracy: 0.4824
# Epoch 47/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.9881 - categorical_accuracy: 0.4353
# Epoch 48/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 1.0109 - categorical_accuracy: 0.5176
# Epoch 49/2000
# 3/3 [==============================] - 0s 166ms/step - loss: 0.9532 - categorical_accuracy: 0.5294
# Epoch 50/2000
# 3/3 [==============================] - 0s 166ms/step - loss: 1.0814 - categorical_accuracy: 0.4471
# Epoch 51/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.0494 - categorical_accuracy: 0.4353
# Epoch 52/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 1.0170 - categorical_accuracy: 0.4588
# Epoch 53/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 1.0239 - categorical_accuracy: 0.3647
# Epoch 54/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 0.9474 - categorical_accuracy: 0.4941
# Epoch 55/2000
# 3/3 [==============================] - 1s 171ms/step - loss: 1.1134 - categorical_accuracy: 0.5412
# Epoch 56/2000
# 3/3 [==============================] - 1s 172ms/step - loss: 1.0581 - categorical_accuracy: 0.4706
# Epoch 57/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 0.9639 - categorical_accuracy: 0.4706
# Epoch 58/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 1.5475 - categorical_accuracy: 0.3647
# Epoch 59/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 2.4597 - categorical_accuracy: 0.3882
# Epoch 60/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 3.4423 - categorical_accuracy: 0.2706
# Epoch 61/2000
# 3/3 [==============================] - 0s 171ms/step - loss: 5.0296 - categorical_accuracy: 0.2353
# Epoch 62/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 2.7954 - categorical_accuracy: 0.3294
# Epoch 63/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 2.3912 - categorical_accuracy: 0.4118
# Epoch 64/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 2.2011 - categorical_accuracy: 0.3294
# Epoch 65/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 3.7361 - categorical_accuracy: 0.3294
# Epoch 66/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 10.2174 - categorical_accuracy: 0.3647
# Epoch 67/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 6.3142 - categorical_accuracy: 0.3059
# Epoch 68/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 7.9920 - categorical_accuracy: 0.3412
# Epoch 69/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 10.8241 - categorical_accuracy: 0.3412
# Epoch 70/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 17.1873 - categorical_accuracy: 0.2941
# Epoch 71/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 162.2929 - categorical_accuracy: 0.3176
# Epoch 72/2000
# 3/3 [==============================] - 1s 173ms/step - loss: 217.1145 - categorical_accuracy: 0.3765
# Epoch 73/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 87.1020 - categorical_accuracy: 0.2824
# Epoch 74/2000
# 3/3 [==============================] - 0s 167ms/step - loss: 199.7977 - categorical_accuracy: 0.3412
# Epoch 75/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 128.5931 - categorical_accuracy: 0.3412
# Epoch 76/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 131.4386 - categorical_accuracy: 0.3647
# Epoch 77/2000
# 3/3 [==============================] - 1s 165ms/step - loss: 183.6340 - categorical_accuracy: 0.3176
# Epoch 78/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 150.7283 - categorical_accuracy: 0.2353
# Epoch 79/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 74.0207 - categorical_accuracy: 0.2118
# Epoch 80/2000
# 3/3 [==============================] - 0s 167ms/step - loss: 47.7778 - categorical_accuracy: 0.3529
# Epoch 81/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 35.4774 - categorical_accuracy: 0.3176
# Epoch 82/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 20.5624 - categorical_accuracy: 0.3882
# Epoch 83/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 14.7261 - categorical_accuracy: 0.3294
# Epoch 84/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 19.7739 - categorical_accuracy: 0.3529
# Epoch 85/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 8.8794 - categorical_accuracy: 0.2118
# Epoch 86/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 9.8342 - categorical_accuracy: 0.3529
# Epoch 87/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 9.6809 - categorical_accuracy: 0.2941
# Epoch 88/2000
# 3/3 [==============================] - 0s 166ms/step - loss: 9.3314 - categorical_accuracy: 0.3529
# Epoch 89/2000
# 3/3 [==============================] - 1s 163ms/step - loss: 6.3136 - categorical_accuracy: 0.3412
# Epoch 90/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 4.2897 - categorical_accuracy: 0.3294
# Epoch 91/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 4.9506 - categorical_accuracy: 0.3529
# Epoch 92/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 2.8289 - categorical_accuracy: 0.2471
# Epoch 93/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 3.1434 - categorical_accuracy: 0.3294
# Epoch 94/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 6.4163 - categorical_accuracy: 0.3412
# Epoch 95/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 3.3489 - categorical_accuracy: 0.3059
# Epoch 96/2000
# 3/3 [==============================] - 1s 167ms/step - loss: 4.1984 - categorical_accuracy: 0.3294
# Epoch 97/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 4.4635 - categorical_accuracy: 0.3294
# Epoch 98/2000
# 3/3 [==============================] - 0s 166ms/step - loss: 4.6238 - categorical_accuracy: 0.2588
# Epoch 99/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 3.6746 - categorical_accuracy: 0.3294
# Epoch 100/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 4.1008 - categorical_accuracy: 0.4353
# Epoch 101/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 4.5234 - categorical_accuracy: 0.3412
# Epoch 102/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 4.6968 - categorical_accuracy: 0.3529
# Epoch 103/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 3.5165 - categorical_accuracy: 0.4118
# Epoch 104/2000
# 3/3 [==============================] - 1s 167ms/step - loss: 3.8367 - categorical_accuracy: 0.3765
# Epoch 105/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 4.4329 - categorical_accuracy: 0.2353
# Epoch 106/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 4.2733 - categorical_accuracy: 0.2588
# Epoch 107/2000
# 3/3 [==============================] - 1s 151ms/step - loss: 3.2516 - categorical_accuracy: 0.4471
# Epoch 108/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 2.6621 - categorical_accuracy: 0.2941
# Epoch 109/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 2.3947 - categorical_accuracy: 0.2941
# Epoch 110/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 2.1623 - categorical_accuracy: 0.3059
# Epoch 111/2000
# 3/3 [==============================] - 1s 168ms/step - loss: 2.2164 - categorical_accuracy: 0.3647
# Epoch 112/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.3979 - categorical_accuracy: 0.3529
# Epoch 113/2000
# 3/3 [==============================] - 1s 173ms/step - loss: 1.3118 - categorical_accuracy: 0.3765
# Epoch 114/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.4025 - categorical_accuracy: 0.4000
# Epoch 115/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.3655 - categorical_accuracy: 0.3765
# Epoch 116/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 1.2854 - categorical_accuracy: 0.3765
# Epoch 117/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 1.6025 - categorical_accuracy: 0.3765
# Epoch 118/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 1.4564 - categorical_accuracy: 0.4353
# Epoch 119/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 1.2627 - categorical_accuracy: 0.4118
# Epoch 120/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 1.4476 - categorical_accuracy: 0.3765
# Epoch 121/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 1.6648 - categorical_accuracy: 0.4588
# Epoch 122/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 1.4469 - categorical_accuracy: 0.5529
# Epoch 123/2000
# 3/3 [==============================] - 0s 164ms/step - loss: 1.2420 - categorical_accuracy: 0.3882
# Epoch 124/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 1.5522 - categorical_accuracy: 0.3176
# Epoch 125/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.2018 - categorical_accuracy: 0.3882
# Epoch 126/2000
# 3/3 [==============================] - 0s 164ms/step - loss: 1.3874 - categorical_accuracy: 0.3529
# Epoch 127/2000
# 3/3 [==============================] - 1s 173ms/step - loss: 1.0832 - categorical_accuracy: 0.5529
# Epoch 128/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 1.4081 - categorical_accuracy: 0.3647
# Epoch 129/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 1.0649 - categorical_accuracy: 0.4588
# Epoch 130/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 1.4375 - categorical_accuracy: 0.3294
# Epoch 131/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 1.1200 - categorical_accuracy: 0.4588
# Epoch 132/2000
# 3/3 [==============================] - 1s 157ms/step - loss: 1.1026 - categorical_accuracy: 0.4706
# Epoch 133/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.0065 - categorical_accuracy: 0.4824
# Epoch 134/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.1488 - categorical_accuracy: 0.4118
# Epoch 135/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 1.1869 - categorical_accuracy: 0.4588
# Epoch 136/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 0.9909 - categorical_accuracy: 0.4706
# Epoch 137/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 1.2297 - categorical_accuracy: 0.4235
# Epoch 138/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 1.2221 - categorical_accuracy: 0.5176
# Epoch 139/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 1.2064 - categorical_accuracy: 0.5294
# Epoch 140/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.4474 - categorical_accuracy: 0.4353
# Epoch 141/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 1.6559 - categorical_accuracy: 0.5176
# Epoch 142/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.3643 - categorical_accuracy: 0.4941
# Epoch 143/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 2.1503 - categorical_accuracy: 0.4353
# Epoch 144/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 2.2399 - categorical_accuracy: 0.3882
# Epoch 145/2000
# 3/3 [==============================] - 1s 171ms/step - loss: 2.9313 - categorical_accuracy: 0.4706
# Epoch 146/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 2.0975 - categorical_accuracy: 0.3294
# Epoch 147/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 1.7735 - categorical_accuracy: 0.3647
# Epoch 148/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 1.2419 - categorical_accuracy: 0.4941
# Epoch 149/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 1.4820 - categorical_accuracy: 0.4941
# Epoch 150/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.4014 - categorical_accuracy: 0.4000
# Epoch 151/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 1.2103 - categorical_accuracy: 0.3647
# Epoch 152/2000
# 3/3 [==============================] - 1s 168ms/step - loss: 1.4024 - categorical_accuracy: 0.4353
# Epoch 153/2000
# 3/3 [==============================] - 1s 172ms/step - loss: 1.1501 - categorical_accuracy: 0.4353
# Epoch 154/2000
# 3/3 [==============================] - 1s 173ms/step - loss: 1.0888 - categorical_accuracy: 0.5059
# Epoch 155/2000
# 3/3 [==============================] - 1s 173ms/step - loss: 1.3039 - categorical_accuracy: 0.4824
# Epoch 156/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.8681 - categorical_accuracy: 0.5882
# Epoch 157/2000
# 3/3 [==============================] - 1s 173ms/step - loss: 0.8505 - categorical_accuracy: 0.6471
# Epoch 158/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.8961 - categorical_accuracy: 0.6118
# Epoch 159/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 0.9753 - categorical_accuracy: 0.4235
# Epoch 160/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 1.2027 - categorical_accuracy: 0.5647
# Epoch 161/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 1.0858 - categorical_accuracy: 0.5647
# Epoch 162/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 0.9306 - categorical_accuracy: 0.5176
# Epoch 163/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 0.8455 - categorical_accuracy: 0.6471
# Epoch 164/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.8001 - categorical_accuracy: 0.5765
# Epoch 165/2000
# 3/3 [==============================] - 1s 172ms/step - loss: 0.7539 - categorical_accuracy: 0.5529
# Epoch 166/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 1.0128 - categorical_accuracy: 0.4588
# Epoch 167/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 1.0046 - categorical_accuracy: 0.5647
# Epoch 168/2000
# 3/3 [==============================] - 1s 171ms/step - loss: 1.4241 - categorical_accuracy: 0.3765
# Epoch 169/2000
# 3/3 [==============================] - 1s 173ms/step - loss: 1.3174 - categorical_accuracy: 0.4235
# Epoch 170/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 2.2339 - categorical_accuracy: 0.5176
# Epoch 171/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 1.8519 - categorical_accuracy: 0.3412
# Epoch 172/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 1.1987 - categorical_accuracy: 0.4588
# Epoch 173/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 1.3891 - categorical_accuracy: 0.4000
# Epoch 174/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 1.9377 - categorical_accuracy: 0.4588
# Epoch 175/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 1.2120 - categorical_accuracy: 0.4353
# Epoch 176/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 2.2858 - categorical_accuracy: 0.3882
# Epoch 177/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 1.7212 - categorical_accuracy: 0.3412
# Epoch 178/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 1.5354 - categorical_accuracy: 0.4235
# Epoch 179/2000
# 3/3 [==============================] - 0s 166ms/step - loss: 1.3359 - categorical_accuracy: 0.4471
# Epoch 180/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 1.4196 - categorical_accuracy: 0.3765
# Epoch 181/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 1.3397 - categorical_accuracy: 0.4588
# Epoch 182/2000
# 3/3 [==============================] - 0s 170ms/step - loss: 1.5719 - categorical_accuracy: 0.4118
# Epoch 183/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 1.8054 - categorical_accuracy: 0.4000
# Epoch 184/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 2.1480 - categorical_accuracy: 0.3529
# Epoch 185/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 1.7491 - categorical_accuracy: 0.3647
# Epoch 186/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 1.7195 - categorical_accuracy: 0.6118
# Epoch 187/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 1.9041 - categorical_accuracy: 0.3294
# Epoch 188/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.6849 - categorical_accuracy: 0.3765
# Epoch 189/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 1.0673 - categorical_accuracy: 0.5176
# Epoch 190/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 1.0867 - categorical_accuracy: 0.4353
# Epoch 191/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 1.2646 - categorical_accuracy: 0.3529
# Epoch 192/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 0.9500 - categorical_accuracy: 0.5765
# Epoch 193/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 0.7998 - categorical_accuracy: 0.6941
# Epoch 194/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.7286 - categorical_accuracy: 0.7529
# Epoch 195/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 0.8083 - categorical_accuracy: 0.6588
# Epoch 196/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.6890 - categorical_accuracy: 0.7412
# Epoch 197/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.8388 - categorical_accuracy: 0.6118
# Epoch 198/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 0.8894 - categorical_accuracy: 0.6000
# Epoch 199/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.4935 - categorical_accuracy: 0.5647
# Epoch 200/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 0.8809 - categorical_accuracy: 0.6235
# Epoch 201/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 0.6945 - categorical_accuracy: 0.7294
# Epoch 202/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 0.8482 - categorical_accuracy: 0.5882
# Epoch 203/2000
# 3/3 [==============================] - 0s 164ms/step - loss: 0.8326 - categorical_accuracy: 0.5765
# Epoch 204/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 0.9506 - categorical_accuracy: 0.6000
# Epoch 205/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 0.8624 - categorical_accuracy: 0.6471
# Epoch 206/2000
# 3/3 [==============================] - 1s 203ms/step - loss: 0.8167 - categorical_accuracy: 0.5529
# Epoch 207/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 7.0479 - categorical_accuracy: 0.4941
# Epoch 208/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 607.5382 - categorical_accuracy: 0.4118
# Epoch 209/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 11.6673 - categorical_accuracy: 0.2941
# Epoch 210/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 11.9398 - categorical_accuracy: 0.3412
# Epoch 211/2000
# 3/3 [==============================] - 1s 166ms/step - loss: 12.0740 - categorical_accuracy: 0.2824
# Epoch 212/2000
# 3/3 [==============================] - 1s 166ms/step - loss: 551.7653 - categorical_accuracy: 0.4235
# Epoch 213/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 10.7626 - categorical_accuracy: 0.3529
# Epoch 214/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 6.7577 - categorical_accuracy: 0.3059
# Epoch 215/2000
# 3/3 [==============================] - 0s 169ms/step - loss: 10.5453 - categorical_accuracy: 0.2588
# Epoch 216/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 8.8729 - categorical_accuracy: 0.3882
# Epoch 217/2000
# 3/3 [==============================] - 1s 168ms/step - loss: 8.3703 - categorical_accuracy: 0.5176
# Epoch 218/2000
# 3/3 [==============================] - 1s 226ms/step - loss: 8.0386 - categorical_accuracy: 0.4235
# Epoch 219/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 9.8945 - categorical_accuracy: 0.3765
# Epoch 220/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 8.8966 - categorical_accuracy: 0.3294
# Epoch 221/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 6.9527 - categorical_accuracy: 0.3294
# Epoch 222/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 5.0874 - categorical_accuracy: 0.3765
# Epoch 223/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 3.2890 - categorical_accuracy: 0.4706
# Epoch 224/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 5.1117 - categorical_accuracy: 0.2706
# Epoch 225/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 7.6471 - categorical_accuracy: 0.4118
# Epoch 226/2000
# 3/3 [==============================] - 1s 164ms/step - loss: 7.3771 - categorical_accuracy: 0.4235
# Epoch 227/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 8.0108 - categorical_accuracy: 0.3529
# Epoch 228/2000
# 3/3 [==============================] - 1s 171ms/step - loss: 5.5456 - categorical_accuracy: 0.4235
# Epoch 229/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 2.8888 - categorical_accuracy: 0.3882
# Epoch 230/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 4.4337 - categorical_accuracy: 0.2706
# Epoch 231/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 4.6684 - categorical_accuracy: 0.4000
# Epoch 232/2000
# 3/3 [==============================] - 0s 167ms/step - loss: 4.1880 - categorical_accuracy: 0.5529
# Epoch 233/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 6.9622 - categorical_accuracy: 0.3176
# Epoch 234/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 4.3846 - categorical_accuracy: 0.4706
# Epoch 235/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 3.3835 - categorical_accuracy: 0.3647
# Epoch 236/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 3.0686 - categorical_accuracy: 0.3882
# Epoch 237/2000
# 3/3 [==============================] - 0s 169ms/step - loss: 2.7775 - categorical_accuracy: 0.4471
# Epoch 238/2000
# 3/3 [==============================] - 1s 166ms/step - loss: 3.6566 - categorical_accuracy: 0.4118
# Epoch 239/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 1.9341 - categorical_accuracy: 0.5647
# Epoch 240/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 1.7192 - categorical_accuracy: 0.5059
# Epoch 241/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 1.7339 - categorical_accuracy: 0.6235
# Epoch 242/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 2.9535 - categorical_accuracy: 0.3294
# Epoch 243/2000
# 3/3 [==============================] - 1s 198ms/step - loss: 1.5705 - categorical_accuracy: 0.5294
# Epoch 244/2000
# 3/3 [==============================] - 1s 209ms/step - loss: 1.5424 - categorical_accuracy: 0.5412
# Epoch 245/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 1.2014 - categorical_accuracy: 0.5647
# Epoch 246/2000
# 3/3 [==============================] - 1s 200ms/step - loss: 1.7526 - categorical_accuracy: 0.5294
# Epoch 247/2000
# 3/3 [==============================] - 1s 232ms/step - loss: 2.6938 - categorical_accuracy: 0.4824
# Epoch 248/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 3.8314 - categorical_accuracy: 0.4235
# Epoch 249/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 2.2665 - categorical_accuracy: 0.4353
# Epoch 250/2000
# 3/3 [==============================] - 1s 211ms/step - loss: 3.9688 - categorical_accuracy: 0.3176
# Epoch 251/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 5.3609 - categorical_accuracy: 0.4000
# Epoch 252/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 3.1642 - categorical_accuracy: 0.5176
# Epoch 253/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 6.6937 - categorical_accuracy: 0.4706
# Epoch 254/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 2.4749 - categorical_accuracy: 0.4941
# Epoch 255/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 3.1547 - categorical_accuracy: 0.4235
# Epoch 256/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 2.7560 - categorical_accuracy: 0.3882
# Epoch 257/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 1.5895 - categorical_accuracy: 0.4706
# Epoch 258/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 2.1778 - categorical_accuracy: 0.4588
# Epoch 259/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 1.4669 - categorical_accuracy: 0.4353
# Epoch 260/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 1.9062 - categorical_accuracy: 0.4000
# Epoch 261/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 2.3873 - categorical_accuracy: 0.4824
# Epoch 262/2000
# 3/3 [==============================] - 1s 167ms/step - loss: 3.0229 - categorical_accuracy: 0.5529
# Epoch 263/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.9509 - categorical_accuracy: 0.4000
# Epoch 264/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 1.5266 - categorical_accuracy: 0.5059
# Epoch 265/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 0.9949 - categorical_accuracy: 0.6471
# Epoch 266/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 1.0802 - categorical_accuracy: 0.6353
# Epoch 267/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.1262 - categorical_accuracy: 0.5176
# Epoch 268/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 0.9556 - categorical_accuracy: 0.6353
# Epoch 269/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.0179 - categorical_accuracy: 0.6824
# Epoch 270/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.2300 - categorical_accuracy: 0.5412
# Epoch 271/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.9756 - categorical_accuracy: 0.6235
# Epoch 272/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.8854 - categorical_accuracy: 0.5765
# Epoch 273/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 1.1067 - categorical_accuracy: 0.5412
# Epoch 274/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 0.9441 - categorical_accuracy: 0.6235
# Epoch 275/2000
# 3/3 [==============================] - 0s 168ms/step - loss: 1.3195 - categorical_accuracy: 0.5059
# Epoch 276/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 1.0257 - categorical_accuracy: 0.6588
# Epoch 277/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.9154 - categorical_accuracy: 0.6706
# Epoch 278/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 1.4278 - categorical_accuracy: 0.6000
# Epoch 279/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 1.1218 - categorical_accuracy: 0.6706
# Epoch 280/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 1.2164 - categorical_accuracy: 0.6941
# Epoch 281/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.6596 - categorical_accuracy: 0.6000
# Epoch 282/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 1.4898 - categorical_accuracy: 0.6235
# Epoch 283/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 1.2341 - categorical_accuracy: 0.6118
# Epoch 284/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 1.1675 - categorical_accuracy: 0.5294
# Epoch 285/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 1.7999 - categorical_accuracy: 0.5647
# Epoch 286/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 1.7905 - categorical_accuracy: 0.5059
# Epoch 287/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 3.6723 - categorical_accuracy: 0.6353
# Epoch 288/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 2.3861 - categorical_accuracy: 0.7412
# Epoch 289/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 2.4459 - categorical_accuracy: 0.4706
# Epoch 290/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 2.4060 - categorical_accuracy: 0.6706
# Epoch 291/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 3.1517 - categorical_accuracy: 0.6235
# Epoch 292/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 2.7455 - categorical_accuracy: 0.4471
# Epoch 293/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 2.2259 - categorical_accuracy: 0.3294
# Epoch 294/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 2.6777 - categorical_accuracy: 0.4353
# Epoch 295/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 2.4009 - categorical_accuracy: 0.4824
# Epoch 296/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 2.8649 - categorical_accuracy: 0.4824
# Epoch 297/2000
# 3/3 [==============================] - 0s 168ms/step - loss: 2.6778 - categorical_accuracy: 0.3647
# Epoch 298/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 2.5635 - categorical_accuracy: 0.3647
# Epoch 299/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 2.5398 - categorical_accuracy: 0.4588
# Epoch 300/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 2.4803 - categorical_accuracy: 0.4118
# Epoch 301/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 2.2019 - categorical_accuracy: 0.3765
# Epoch 302/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 2.7468 - categorical_accuracy: 0.3882
# Epoch 303/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 4.1035 - categorical_accuracy: 0.4471
# Epoch 304/2000
# 3/3 [==============================] - 0s 170ms/step - loss: 2.5883 - categorical_accuracy: 0.3882
# Epoch 305/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 2.7064 - categorical_accuracy: 0.3882
# Epoch 306/2000
# 3/3 [==============================] - 1s 186ms/step - loss: 2.0030 - categorical_accuracy: 0.4471
# Epoch 307/2000
# 3/3 [==============================] - 1s 221ms/step - loss: 2.9990 - categorical_accuracy: 0.4118
# Epoch 308/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 2.7283 - categorical_accuracy: 0.4118
# Epoch 309/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 3.1409 - categorical_accuracy: 0.4353
# Epoch 310/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 2.5043 - categorical_accuracy: 0.4000
# Epoch 311/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 2.5192 - categorical_accuracy: 0.4588
# Epoch 312/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 1.8768 - categorical_accuracy: 0.4353
# Epoch 313/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 1.4574 - categorical_accuracy: 0.4235
# Epoch 314/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 1.4264 - categorical_accuracy: 0.4824
# Epoch 315/2000
# 3/3 [==============================] - 0s 171ms/step - loss: 1.2206 - categorical_accuracy: 0.4588
# Epoch 316/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 1.2962 - categorical_accuracy: 0.4824
# Epoch 317/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 1.0751 - categorical_accuracy: 0.5176
# Epoch 318/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 1.0535 - categorical_accuracy: 0.5294
# Epoch 319/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 1.0909 - categorical_accuracy: 0.5294
# Epoch 320/2000
# 3/3 [==============================] - 1s 221ms/step - loss: 1.6504 - categorical_accuracy: 0.5294
# Epoch 321/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 1.3956 - categorical_accuracy: 0.4471
# Epoch 322/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 1.4949 - categorical_accuracy: 0.5176
# Epoch 323/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 1.7720 - categorical_accuracy: 0.4000
# Epoch 324/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 1.5141 - categorical_accuracy: 0.4118
# Epoch 325/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.0983 - categorical_accuracy: 0.5294
# Epoch 326/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 1.7165 - categorical_accuracy: 0.4706
# Epoch 327/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 1.4478 - categorical_accuracy: 0.4353
# Epoch 328/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 1.4374 - categorical_accuracy: 0.4588
# Epoch 329/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 1.1581 - categorical_accuracy: 0.4941
# Epoch 330/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 1.8311 - categorical_accuracy: 0.4706
# Epoch 331/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 2.3832 - categorical_accuracy: 0.4941
# Epoch 332/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 2.1542 - categorical_accuracy: 0.4588
# Epoch 333/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 1.8630 - categorical_accuracy: 0.4588
# Epoch 334/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 2.0759 - categorical_accuracy: 0.4000
# Epoch 335/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 2.4372 - categorical_accuracy: 0.4000
# Epoch 336/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.7658 - categorical_accuracy: 0.6000
# Epoch 337/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.3842 - categorical_accuracy: 0.5059
# Epoch 338/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 1.7272 - categorical_accuracy: 0.3882
# Epoch 339/2000
# 3/3 [==============================] - 1s 180ms/step - loss: 2.1159 - categorical_accuracy: 0.4118
# Epoch 340/2000
# 3/3 [==============================] - 1s 165ms/step - loss: 3.5591 - categorical_accuracy: 0.2706
# Epoch 341/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 1.8588 - categorical_accuracy: 0.4588
# Epoch 342/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 1.5212 - categorical_accuracy: 0.4706
# Epoch 343/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 1.1671 - categorical_accuracy: 0.5176
# Epoch 344/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 1.1980 - categorical_accuracy: 0.3882
# Epoch 345/2000
# 3/3 [==============================] - 0s 172ms/step - loss: 1.4283 - categorical_accuracy: 0.5059
# Epoch 346/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 1.3109 - categorical_accuracy: 0.4706
# Epoch 347/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 1.3184 - categorical_accuracy: 0.5647
# Epoch 348/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 1.4391 - categorical_accuracy: 0.4706
# Epoch 349/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.8496 - categorical_accuracy: 0.5412
# Epoch 350/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 0.9893 - categorical_accuracy: 0.6000
# Epoch 351/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 1.5035 - categorical_accuracy: 0.5294
# Epoch 352/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 1.7085 - categorical_accuracy: 0.6353
# Epoch 353/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 2.0195 - categorical_accuracy: 0.4353
# Epoch 354/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 1.4663 - categorical_accuracy: 0.3882
# Epoch 355/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 2.7432 - categorical_accuracy: 0.3882
# Epoch 356/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 3.5571 - categorical_accuracy: 0.4235
# Epoch 357/2000
# 3/3 [==============================] - 0s 164ms/step - loss: 3.3820 - categorical_accuracy: 0.5412
# Epoch 358/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 2.1019 - categorical_accuracy: 0.5412
# Epoch 359/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 3.3606 - categorical_accuracy: 0.4235
# Epoch 360/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 3.6904 - categorical_accuracy: 0.3765
# Epoch 361/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 3.6000 - categorical_accuracy: 0.3412
# Epoch 362/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 2.2850 - categorical_accuracy: 0.3882
# Epoch 363/2000
# 3/3 [==============================] - 0s 168ms/step - loss: 2.1602 - categorical_accuracy: 0.5176
# Epoch 364/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.4712 - categorical_accuracy: 0.4706
# Epoch 365/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 1.0052 - categorical_accuracy: 0.5412
# Epoch 366/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 0.8187 - categorical_accuracy: 0.5647
# Epoch 367/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 0.9277 - categorical_accuracy: 0.5059
# Epoch 368/2000
# 3/3 [==============================] - 0s 167ms/step - loss: 1.0241 - categorical_accuracy: 0.5059
# Epoch 369/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 0.9493 - categorical_accuracy: 0.4941
# Epoch 370/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 0.7992 - categorical_accuracy: 0.6353
# Epoch 371/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 0.9360 - categorical_accuracy: 0.4706
# Epoch 372/2000
# 3/3 [==============================] - 1s 165ms/step - loss: 1.3161 - categorical_accuracy: 0.4588
# Epoch 373/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 0.8711 - categorical_accuracy: 0.5882
# Epoch 374/2000
# 3/3 [==============================] - 1s 165ms/step - loss: 1.1923 - categorical_accuracy: 0.4235
# Epoch 375/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 1.2319 - categorical_accuracy: 0.4588
# Epoch 376/2000
# 3/3 [==============================] - 1s 162ms/step - loss: 1.0244 - categorical_accuracy: 0.6235
# Epoch 377/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 1.3531 - categorical_accuracy: 0.5059
# Epoch 378/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.8044 - categorical_accuracy: 0.5765
# Epoch 379/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 1.0411 - categorical_accuracy: 0.5294
# Epoch 380/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 1.9205 - categorical_accuracy: 0.6118
# Epoch 381/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 1.2672 - categorical_accuracy: 0.5059
# Epoch 382/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 2.7831 - categorical_accuracy: 0.6235
# Epoch 383/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 2.2883 - categorical_accuracy: 0.4235
# Epoch 384/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 1.7042 - categorical_accuracy: 0.6471
# Epoch 385/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 1.6218 - categorical_accuracy: 0.5176
# Epoch 386/2000
# 3/3 [==============================] - 1s 152ms/step - loss: 1.4438 - categorical_accuracy: 0.6235
# Epoch 387/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 0.9065 - categorical_accuracy: 0.6235
# Epoch 388/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.1325 - categorical_accuracy: 0.6706
# Epoch 389/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 1.7819 - categorical_accuracy: 0.5059
# Epoch 390/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 2.0278 - categorical_accuracy: 0.4471
# Epoch 391/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.4621 - categorical_accuracy: 0.5176
# Epoch 392/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 1.4641 - categorical_accuracy: 0.4824
# Epoch 393/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 1.1809 - categorical_accuracy: 0.4706
# Epoch 394/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 2.1226 - categorical_accuracy: 0.5882
# Epoch 395/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 2.4838 - categorical_accuracy: 0.5529
# Epoch 396/2000
# 3/3 [==============================] - 0s 164ms/step - loss: 2.0839 - categorical_accuracy: 0.6353
# Epoch 397/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.4284 - categorical_accuracy: 0.5765
# Epoch 398/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.7819 - categorical_accuracy: 0.6941
# Epoch 399/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.9169 - categorical_accuracy: 0.6235
# Epoch 400/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 1.2162 - categorical_accuracy: 0.6000
# Epoch 401/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 1.1011 - categorical_accuracy: 0.6471
# Epoch 402/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.5794 - categorical_accuracy: 0.8118
# Epoch 403/2000
# 3/3 [==============================] - 1s 165ms/step - loss: 0.7266 - categorical_accuracy: 0.6235
# Epoch 404/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.6631 - categorical_accuracy: 0.6706
# Epoch 405/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.5385 - categorical_accuracy: 0.7765
# Epoch 406/2000
# 3/3 [==============================] - 0s 169ms/step - loss: 0.5702 - categorical_accuracy: 0.6941
# Epoch 407/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.5114 - categorical_accuracy: 0.7882
# Epoch 408/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.5267 - categorical_accuracy: 0.8000
# Epoch 409/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 0.5655 - categorical_accuracy: 0.7882
# Epoch 410/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 0.6166 - categorical_accuracy: 0.6588
# Epoch 411/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.0073 - categorical_accuracy: 0.6000
# Epoch 412/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.1844 - categorical_accuracy: 0.6000
# Epoch 413/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.8126 - categorical_accuracy: 0.6000
# Epoch 414/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 1.6537 - categorical_accuracy: 0.6353
# Epoch 415/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 1.3042 - categorical_accuracy: 0.7176
# Epoch 416/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 0.9963 - categorical_accuracy: 0.7176
# Epoch 417/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 2.5356 - categorical_accuracy: 0.6941
# Epoch 418/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 2.0190 - categorical_accuracy: 0.5412
# Epoch 419/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 1.3895 - categorical_accuracy: 0.7412
# Epoch 420/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 1.4580 - categorical_accuracy: 0.7059
# Epoch 421/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 1.6820 - categorical_accuracy: 0.6706
# Epoch 422/2000
# ...
# Epoch 1867/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 3.4254e-05 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 3.3825e-05 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 3.3822e-05 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 3.3588e-05 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 3.3567e-05 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 3/3 [==============================] - 0s 136ms/step - loss: 3.3574e-05 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 3.3500e-05 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 3.3252e-05 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 3.2977e-05 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 3/3 [==============================] - 1s 168ms/step - loss: 3.3002e-05 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 3.2841e-05 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 3.2663e-05 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 3/3 [==============================] - 1s 159ms/step - loss: 3.2486e-05 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 3/3 [==============================] - 1s 212ms/step - loss: 3.2443e-05 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 3/3 [==============================] - 1s 173ms/step - loss: 3.2533e-05 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 3.2184e-05 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 3.2226e-05 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 3.1979e-05 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 3.2003e-05 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 3.1756e-05 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 3/3 [==============================] - 1s 148ms/step - loss: 3.1649e-05 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 3.1574e-05 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 3.1697e-05 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 3/3 [==============================] - 1s 262ms/step - loss: 3.1282e-05 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 3.1190e-05 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 3.1055e-05 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 3.1007e-05 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 3/3 [==============================] - 1s 196ms/step - loss: 3.0769e-05 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 3.0735e-05 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 3/3 [==============================] - 1s 243ms/step - loss: 3.0937e-05 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 3/3 [==============================] - 1s 246ms/step - loss: 3.0540e-05 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 3.0718e-05 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 3.0382e-05 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 3/3 [==============================] - 1s 248ms/step - loss: 3.0170e-05 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 3.0180e-05 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 2.9952e-05 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 3.0225e-05 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 3/3 [==============================] - 1s 212ms/step - loss: 2.9740e-05 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 2.9650e-05 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 2.9670e-05 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 2.9482e-05 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 2.9769e-05 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 3/3 [==============================] - 1s 191ms/step - loss: 2.9266e-05 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 2.9136e-05 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 2.9025e-05 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 2.8869e-05 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 3/3 [==============================] - 0s 172ms/step - loss: 2.8794e-05 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 2.8839e-05 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 2.8663e-05 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 2.8606e-05 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 2.8431e-05 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 2.8433e-05 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 2.8321e-05 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 2.8237e-05 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 2.8215e-05 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 3/3 [==============================] - 1s 227ms/step - loss: 2.7992e-05 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 3/3 [==============================] - 1s 196ms/step - loss: 2.7931e-05 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 3/3 [==============================] - 1s 210ms/step - loss: 2.7888e-05 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 2.7871e-05 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 2.7646e-05 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 3/3 [==============================] - 1s 151ms/step - loss: 2.7623e-05 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 2.7361e-05 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 2.7298e-05 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 3/3 [==============================] - 0s 171ms/step - loss: 2.7186e-05 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 2.7410e-05 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 3/3 [==============================] - 1s 139ms/step - loss: 2.7137e-05 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 2.7034e-05 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 2.6876e-05 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 3/3 [==============================] - 1s 229ms/step - loss: 2.6709e-05 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 2.6741e-05 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 2.6482e-05 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 2.6513e-05 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 2.6409e-05 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 3/3 [==============================] - 1s 224ms/step - loss: 2.6490e-05 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 2.6301e-05 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 2.6252e-05 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 2.6042e-05 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 2.5925e-05 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 3/3 [==============================] - 1s 215ms/step - loss: 2.5913e-05 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 2.5781e-05 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 2.5771e-05 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 2.5669e-05 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 3/3 [==============================] - 1s 180ms/step - loss: 2.5554e-05 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 2.5463e-05 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 2.5408e-05 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 2.5394e-05 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 2.5227e-05 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 3/3 [==============================] - 1s 155ms/step - loss: 2.5187e-05 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 2.5119e-05 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 2.4982e-05 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 2.4947e-05 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 2.4992e-05 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 2.4805e-05 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 2.4889e-05 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 3/3 [==============================] - 1s 148ms/step - loss: 2.4706e-05 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 2.4512e-05 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 2.4565e-05 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 2.4368e-05 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 3/3 [==============================] - 1s 205ms/step - loss: 2.4331e-05 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 2.4275e-05 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 2.4166e-05 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 3/3 [==============================] - 0s 173ms/step - loss: 2.4240e-05 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 2.4063e-05 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 2.4079e-05 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 2.4066e-05 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 3/3 [==============================] - 1s 160ms/step - loss: 2.3863e-05 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 2.3730e-05 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 2.3602e-05 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 2.3684e-05 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 2.3539e-05 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 2.3416e-05 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 2.3521e-05 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 2.3311e-05 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 3/3 [==============================] - 1s 155ms/step - loss: 2.3130e-05 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 2.3145e-05 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 2.3086e-05 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 3/3 [==============================] - 0s 173ms/step - loss: 2.3152e-05 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 2.2953e-05 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 2.3072e-05 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 3/3 [==============================] - 1s 166ms/step - loss: 2.2908e-05 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 3/3 [==============================] - 1s 180ms/step - loss: 2.2629e-05 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 3/3 [==============================] - 0s 165ms/step - loss: 2.2577e-05 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 3/3 [==============================] - 0s 167ms/step - loss: 2.2684e-05 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 2.2622e-05 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 3/3 [==============================] - 1s 162ms/step - loss: 2.2388e-05 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 3/3 [==============================] - 1s 164ms/step - loss: 2.2268e-05 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 2.2218e-05 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 3/3 [==============================] - 0s 163ms/step - loss: 2.2217e-05 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 3/3 [==============================] - 1s 164ms/step - loss: 2.2223e-05 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 2.2106e-05 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 2.1961e-05 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 3/3 [==============================] - 0s 166ms/step - loss: 2.1893e-05 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 3/3 [==============================] - 1s 166ms/step - loss: 2.1805e-05 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 2.1810e-05 - categorical_accuracy: 1.0000

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 601ms/step

# %%
actions[np.argmax(res[1])]
# Out:
# 'thanks'

# %%
actions[np.argmax(y_test[1])]
# Out:
# 'thanks'

# %%
# model.save('action.h5')
# Out:
# c:\ProgramData\anaconda3\envs\signspeak\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.save('my_model_2.keras')

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.8
model = load_model('my_model_2.keras')
cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
        # if res[np.argmax(res)] > threshold: 
        #     if len(sentence) > 0: 
        #         if actions[np.argmax(res)] != sentence[-1]:
        #                 sentence.append(actions[np.argmax(res)])
        #         else:
        #             sentence.append(actions[np.argmax(res)])

        #     if len(sentence) > 5: 
        #         sentence = sentence[-5:]

        # Viz probabilities
        # image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
